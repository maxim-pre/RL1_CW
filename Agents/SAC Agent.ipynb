# %%
import numpy as np
import tensorflow as tf
from keras.optimizers import Adam
from keras.models import clone_model
import gymnasium as gym
import tensorflow_probability as tfp
# Out:
# WARNING:tensorflow:From C:\Users\louie\OneDrive - University of Bath\.venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\louie\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From C:\Users\louie\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.

# %%
class SACAgent:

    def __init__(self,
                 env,
                 critic_network1,
                 critic_network2,
                 actor_network,
                 critic_learning_rate=1e-3,
                 actor_learning_rate=1e-3,
                 minibatch_size=100,
                 tau=0.005,
                 warm_up=1000,
                 alpha=0.05,
                 max_buffer_length=1_000_000):
        self.env = env
        self.state_size = env.observation_space.shape[0]
        self.action_size = env.action_space.shape[0]
        self.action_min, self.action_max = env.action_space.low, env.action_space.high

        # Initialize critic network 1 and target critic network 1.
        self.critic_network1 = clone_model(critic_network1)
        self.critic_network1.set_weights(critic_network1.get_weights())

        self.target_critic_network1 = clone_model(critic_network1)
        self.target_critic_network1.set_weights(critic_network1.get_weights())

        # Initialize critic network 2 and target critic network 2.
        self.critic_network2 = clone_model(critic_network2)
        self.critic_network2.set_weights(critic_network2.get_weights())

        self.target_critic_network2 = clone_model(critic_network2)
        self.target_critic_network2.set_weights(critic_network2.get_weights())

        # Initialize actor network.
        self.actor_network = clone_model(actor_network)
        self.actor_network.set_weights(actor_network.get_weights())

        # Initialize network optimizers.
        self.critic1_optimizer = Adam(learning_rate=critic_learning_rate)
        self.critic2_optimizer = Adam(learning_rate=critic_learning_rate)
        self.actor_optimizer = Adam(learning_rate=actor_learning_rate)

        # Initialize hyperparameters.
        self.tau = tau
        self.minibatch_size = minibatch_size
        self.warm_up = warm_up
        self.alpha = alpha

        # Initialize buffer.
        self.buffer_width = 2 * self.state_size + self.action_size + 2
        self.max_buffer_length = max_buffer_length
        self.replay_buffer = np.zeros((self.max_buffer_length, self.buffer_width), dtype=np.float32)
        self.buffer_write_idx = 0
        self.buffer_fullness = 0

        # Initialize minibatch slicers.
        self.state_slice = slice(0, self.state_size)
        self.state_action_slice = slice(0, self.state_size + self.action_size)
        self.reward_slice = slice(self.state_size + self.action_size, self.state_size + self.action_size + 1)
        self.next_state_slice = slice(self.state_size + self.action_size + 1, 2 * self.state_size + self.action_size + 1)
        self.terminal_slice = slice(2 * self.state_size + self.action_size + 1, 2 * self.state_size + self.action_size + 2)

    def select_action(self, state: np.ndarray) -> np.ndarray:
        """Select an action at the given state."""
        # Input check.
        assert state.ndim == 1 and state.shape[0] == 24
        # Do forward pass.
        mean, log_std = (output.numpy()[0] for output in self.actor_network(np.expand_dims(state, axis=0), training=False))
        std = np.exp(log_std)
        epsilon = np.random.normal(size=mean.shape)
        return np.tanh(mean + std * epsilon)

    def save_transition(self, state: np.ndarray, action: np.ndarray, reward: float, new_state: np.ndarray, terminal: bool):
        """Save a transition."""
        # Input check.
        assert state.ndim == 1 and state.shape[0] == self.state_size
        assert action.ndim == 1 and action.shape[0] == self.action_size
        assert new_state.ndim == 1 and new_state.shape[0] == self.state_size

        # Save transition.
        transition = np.concatenate((state, action, [reward], new_state, [1.0 if terminal else 0.0]), dtype=np.float32)
        self.replay_buffer[self.buffer_write_idx] = transition

        # Update write index and fullness.
        self.buffer_write_idx = (self.buffer_write_idx + 1) % self.max_buffer_length
        self.buffer_fullness = min(self.buffer_fullness + 1, self.max_buffer_length)

    def sample_minibatch(self) -> tf.Tensor:
        """Sample a minibatch from the replay buffer."""
        indices = np.random.choice(self.buffer_fullness, size=self.minibatch_size, replace=False)
        minibatch = self.replay_buffer[indices]
        return tf.convert_to_tensor(minibatch, dtype=tf.float32)

    #@tf.function
    def update_critic_networks(self, minibatch: tf.Tensor):
        """Update the critic networks."""
        mb_state_actions = minibatch[:, self.state_action_slice]
        mb_rewards = minibatch[:, self.reward_slice]
        mb_next_states = minibatch[:, self.next_state_slice]
        mb_terminals = minibatch[:, self.terminal_slice]

        mean, log_std = self.actor_network(mb_next_states, training=False)
        std = tf.exp(log_std)
        epsilon = tf.random.normal(shape=mean.shape)
        next_actions_raw = mean + epsilon * std
        next_actions = tf.tanh(next_actions_raw)

        normal = tfp.distributions.Normal(mean, std)
        log_prob_normal = tf.reduce_sum(normal.log_prob(next_actions_raw), axis=-1, keepdims=True)
        tanh_correction = tf.reduce_sum(tf.math.log(1 - tf.tanh(next_actions_raw)**2), axis=-1, keepdims=True)
        log_prob = log_prob_normal - tanh_correction

        next_state_actions = tf.concat((mb_next_states, next_actions), axis=1)
        q1_next = self.target_critic_network1(next_state_actions, training=False)
        q2_next = self.target_critic_network2(next_state_actions, training=False)
        q_min_next = tf.minimum(q1_next, q2_next)
        q_target = mb_rewards + (1 - mb_terminals) * (q_min_next - self.alpha * log_prob)
        print(q_target)

    @tf.function
    def update_actor_network(self, minibatch: tf.Tensor):
        pass

    def learn(self, n_episodes=1000):

        episode_rewards = []

        for n in range(n_episodes):
            # Print episode number.
            print("Episode:", n + 1)

            # Reset environment.
            state, _ = self.env.reset()

            episode_reward = 0 # Monitor reward.

            while True:
                # Select action.
                action = self.select_action(state)

                # Take step.
                new_state, reward, terminal, truncated, _ = self.env.step(action)

                # Store transition.
                self.save_transition(state, action, reward, new_state, terminal)

                # Update episode reward
                episode_reward += reward

                if self.buffer_fullness >= self.minibatch_size and self.buffer_fullness >= self.warm_up:
                    # Sample minibatch.
                    minibatch = self.sample_minibatch()

                    # Update critic networks.
                    self.update_critic_networks(minibatch)

# %%
from keras.models import Sequential, Model
from keras.layers import Input, Dense
from keras.initializers import RandomUniform

critic_network1 = Sequential([
    Input(shape=(28,)),
    Dense(256, activation="relu", kernel_initializer="he_uniform"),
    Dense(256, activation="relu", kernel_initializer="he_uniform"),
    Dense(1, activation="linear", kernel_initializer=RandomUniform(-0.003, 0.003))  # No activation.
])

critic_network2 = Sequential([
    Input(shape=(28,)),
    Dense(256, activation="relu", kernel_initializer="he_uniform"),
    Dense(256, activation="relu", kernel_initializer="he_uniform"),
    Dense(1, activation="linear", kernel_initializer=RandomUniform(-0.003, 0.003))  # No activation.
])

log_std_min = -20
log_std_max = 2

actor_input = Input(shape=(24,))
actor_fcl1 = Dense(256, activation="relu", kernel_initializer="he_uniform")(actor_input)
actor_fcl2 = Dense(256, activation="relu", kernel_initializer="he_uniform")(actor_fcl1)
mean_head = Dense(4, activation="linear", kernel_initializer="he_uniform")(actor_fcl2)
log_std_head = Dense(4, activation="linear", kernel_initializer="he_uniform")(actor_fcl2)
actor_network = Model(inputs=actor_input, outputs=[mean_head, log_std_head])

# %%
env = gym.make("BipedalWalker-v3", hardcore=False, render_mode=None)
# Out:
# C:\Users\louie\OneDrive - University of Bath\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
test = SACAgent(env, critic_network1, critic_network2, actor_network)

test.learn()
# Out:
# Episode: 1
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 7.3829532e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-3.2360002e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.5363693e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [ 1.39478311e-01]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [ 1.13830626e-01]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [ 9.39764082e-04]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-8.42340589e-02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 7.6279745e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 3.5055110e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-5.0381297e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-9.0427339e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.5265688e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.9620445e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 8.7296322e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-2.2825660e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-5.5097818e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.1283098e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.9628672e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.1650054e-01]
#  [-3.2327202e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.6561574e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-2.9106355e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-8.1196390e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [  -0.625237  ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [  -0.42281654]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [  -0.1236802 ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [  -0.11134904]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]
#  [-100.        ]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.2898894e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-2.1365206e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 7.3074088e-02]
#  [-1.0000000e+02]
#  [-4.4872180e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-4.3261188e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-2.1273664e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 8.8191368e-02]
#  [-6.4484888e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-3.4676993e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-9.2814267e-03]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.2226484e-01]
#  [-1.0000000e+02]
#  [ 1.5495479e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 2.7023191e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 2.4513726e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-9.4075114e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-3.4222904e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-5.8412284e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0267636e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 3.0793726e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 8.5803896e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.2864417e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 7.4667379e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 2.5091812e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 4.7937460e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 9.2260875e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.6885811e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 7.1700461e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 9.3736336e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.2818189e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[ 5.1752627e-03]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.2969530e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.9301716e-02]
#  [ 3.3210671e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-6.3944650e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.4266701e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-9.5289417e-02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-3.9763927e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 7.1440771e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 2.8951406e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-6.6582263e-02]
#  [-1.0000000e+02]
#  [ 3.7768081e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-3.3873981e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-6.7608058e-04]
#  [ 8.4814057e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-2.1534114e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.0028853e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.4276896e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 5.9406310e-03]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-4.8328269e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-2.1674871e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-3.3554474e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.3555815e-02]
#  [-1.3974477e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.00000000e+02]
#  [ 1.05174808e-02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [ 1.02079555e-01]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-3.95559847e-01]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-7.95934424e-02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.58569932e-01]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-4.5255435e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-2.8881669e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.3418846e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-9.0163469e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.6494015e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 2.6237488e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 3.2120869e-03]
#  [ 5.1571511e-02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [ 7.75488690e-02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.14028618e-01]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-7.27103710e-01]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.05765022e-01]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.05667420e-01]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.17363535e-01]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]
#  [-1.00000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-8.3343759e-03]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.5133183e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.6060196e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-4.2430699e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 3.7019700e-04]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-8.1628934e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.7952956e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 2.1567559e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 3.0580842e-01]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-9.2085324e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.9209704e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.5978450e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.4391053e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.1410073e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-2.9293159e-01]
#  [-5.8839176e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.1922336e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-2.0553952e-01]
#  [-4.1931742e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.3389403e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.4549676e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 6.8150632e-02]
#  [-1.0000000e+02]
#  [-9.0146691e-02]
#  [-1.0000000e+02]
#  [ 7.9406798e-02]
#  [ 8.3848741e-03]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 3.2672383e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 2.0172209e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.1407944e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.5514158e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 2.5556022e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 4.0436849e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-7.2972283e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 4.2033594e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-2.8240472e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-6.7613065e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-6.4667389e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.2773234e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0342135e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-7.3911674e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-3.2730159e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.4943812e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.8967427e-03]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 2.6107177e-02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]], shape=(100, 1), dtype=float32)
# log_prob_normal: (100, 1)
# tanh_correction: (100, 1)
# log_prob: (100, 1)
# q_min_next: (100, 1)
# tf.Tensor(
# [[-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.2001333e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.4962651e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-4.1440901e-01]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [-1.0000000e+02]
#  [ 1.7768301e-02]
#  [-9.2023179e-02]
#  [-1.0000000e+02]
# ...
# --> 117 q1_next = self.target_critic_network1(next_state_actions, training=False)
#     118 q2_next = self.target_critic_network2(next_state_actions, training=False)
#     119 q_min_next = tf.minimum(q1_next, q2_next)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\layers\layer.py:941, in Layer.__call__(self, *args, **kwargs)
#     939         outputs = super().__call__(*args, **kwargs)
#     940 else:
# --> 941     outputs = super().__call__(*args, **kwargs)
#     942 # Change the layout for the layer output if needed.
#     943 # This is useful for relayout intermediate tensor in the model
#     944 # to achieve the optimal performance.
#     945 distribution = distribution_lib.distribution()
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\ops\operation.py:59, in Operation.__call__(self, *args, **kwargs)
#      54                 call_fn = self.call
#      55     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56         call_fn,
#      57         object_name=(f"{self.__class__.__name__}.call()"),
#      58     )
# ---> 59     return call_fn(*args, **kwargs)
#      61 # Plain flow.
#      62 if any_symbolic_tensors(args, kwargs):
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\models\sequential.py:220, in Sequential.call(self, inputs, training, mask, **kwargs)
#     218 def call(self, inputs, training=None, mask=None, **kwargs):
#     219     if self._functional:
# --> 220         return self._functional.call(
#     221             inputs, training=training, mask=mask, **kwargs
#     222         )
#     224     # Fallback: Just apply the layer sequence.
#     225     # This typically happens if `inputs` is a nested struct.
#     226     for layer in self.layers:
#     227         # During each iteration, `inputs` are the inputs to `layer`, and
#     228         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     229         # end of each iteration `inputs` is set to `outputs` to prepare for
#     230         # the next layer.
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\models\functional.py:183, in Functional.call(self, inputs, training, mask, **kwargs)
#     181         if mask is not None:
#     182             backend.set_keras_mask(x, mask)
# --> 183 outputs = self._run_through_graph(
#     184     inputs,
#     185     operation_fn=lambda op: operation_fn(
#     186         op, training=training, **kwargs
#     187     ),
#     188 )
#     189 return unpack_singleton(outputs)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\ops\function.py:206, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     204     operation = self._get_operation_for_node(node)
#     205     op = operation_fn(operation)
# --> 206     outputs = op(*args, **kwargs)
#     208 # Update tensor_dict.
#     209 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\models\functional.py:644, in operation_fn.<locals>.call(*args, **kwargs)
#     638     if (
#     639         name in getattr(operation, "_call_context_args", {})
#     640         and value is not None
#     641     ):
#     642         kwargs[name] = value
# --> 644 return operation(*args, **kwargs)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\layers\layer.py:941, in Layer.__call__(self, *args, **kwargs)
#     939         outputs = super().__call__(*args, **kwargs)
#     940 else:
# --> 941     outputs = super().__call__(*args, **kwargs)
#     942 # Change the layout for the layer output if needed.
#     943 # This is useful for relayout intermediate tensor in the model
#     944 # to achieve the optimal performance.
#     945 distribution = distribution_lib.distribution()
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\ops\operation.py:59, in Operation.__call__(self, *args, **kwargs)
#      54                 call_fn = self.call
#      55     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56         call_fn,
#      57         object_name=(f"{self.__class__.__name__}.call()"),
#      58     )
# ---> 59     return call_fn(*args, **kwargs)
#      61 # Plain flow.
#      62 if any_symbolic_tensors(args, kwargs):
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\layers\core\dense.py:187, in Dense.call(self, inputs, training)
#     186 def call(self, inputs, training=None):
# --> 187     x = ops.matmul(inputs, self.kernel)
#     188     if self.bias is not None:
#     189         x = ops.add(x, self.bias)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\ops\numpy.py:4607, in matmul(x1, x2)
#    4605 if any_symbolic_tensors((x1, x2)):
#    4606     return Matmul().symbolic_call(x1, x2)
# -> 4607 return backend.numpy.matmul(x1, x2)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\backend\tensorflow\numpy.py:520, in matmul(x1, x2)
#     518     output_type = None
#     519 x1 = tf.cast(x1, compute_dtype)
# --> 520 x2 = tf.cast(x2, compute_dtype)
#     522 def with_combined_batch_dimensions(a, b, output_shape, fn_3d):
#     523     a_sparse = isinstance(a, tf.SparseTensor)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\util\dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\ops\math_ops.py:1012, in cast(x, dtype, name)
#    1006   x = indexed_slices.IndexedSlices(values_cast, x.indices, x.dense_shape)
#    1007 else:
#    1008   # TODO(josh11b): If x is not already a Tensor, we could return
#    1009   # ops.convert_to_tensor(x, dtype=dtype, ...)  here, but that
#    1010   # allows some conversions that cast() can't do, e.g. casting numbers to
#    1011   # strings.
# -> 1012   x = ops.convert_to_tensor(x, name="x")
#    1013   if x.dtype.is_complex and base_type.is_floating:
#    1014     logging.warn(
#    1015         f"You are casting an input of type {x.dtype.name} to an "
#    1016         f"incompatible dtype {base_type.name}.  This will "
#    1017         "discard the imaginary part and may not be what you "
#    1018         "intended."
#    1019     )
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:757, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     755 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     756 preferred_dtype = preferred_dtype or dtype_hint
# --> 757 return tensor_conversion_registry.convert(
#     758     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     759 )
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:84, in Variable.__tf_tensor__(self, dtype, name)
#      83 def __tf_tensor__(self, dtype=None, name=None):
# ---> 84     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\util\dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\framework\tensor_conversion.py:161, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#      96 @tf_export.tf_export("convert_to_tensor", v1=[])
#      97 @dispatch.add_dispatch_support
#      98 def convert_to_tensor_v2_with_dispatch(
#      99     value, dtype=None, dtype_hint=None, name=None
#     100 ) -> tensor_lib.Tensor:
#     101   """Converts the given `value` to a `Tensor`.
#     102
#     103   This function converts Python objects of various types to `Tensor`
#    (...)    159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\framework\tensor_conversion.py:171, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169 """Converts the given `value` to a `Tensor`."""
#     170 # preferred_dtype = preferred_dtype or dtype_hint
# --> 171 return tensor_conversion_registry.convert(
#     172     value, dtype, name, preferred_dtype=dtype_hint
#     173 )
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)    230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:2378, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2377 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2378   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1624, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1622   return self.read_value().op.inputs[0]
#    1623 else:
# -> 1624   return self.value()
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:658, in BaseResourceVariable.value(self)
#     656   return self._cached_value
#     657 with ops.colocate_with(None, ignore_existing=True):
# --> 658   return self._read_variable_op()
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:843, in BaseResourceVariable._read_variable_op(self, no_copy)
#     841       result = read_and_set_handle(no_copy)
#     842 else:
# --> 843   result = read_and_set_handle(no_copy)
#     845 if not context.executing_eagerly():
#     846   # Note that if a control flow context is active the input of the read op
#     847   # might not actually be the handle. This line bypasses it.
#     848   record.record_operation(
#     849       "ReadVariableOp", [result], [self.handle],
#     850       backward_function=lambda x: [x],
#     851       forward_function=lambda x: [x])
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:833, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     831 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     832   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 833 result = gen_resource_variable_ops.read_variable_op(
#     834     self.handle, self._dtype)
#     835 _maybe_set_handle_data(self._dtype, self.handle, result)
#     836 return result
#
# File ~\OneDrive - University of Bath\.venv\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:534, in read_variable_op(resource, dtype, name)
#     532 if tld.is_eager:
#     533   try:
# --> 534     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     535       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     536     return _result
#     537   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
